# %% [markdown]
# <a href="https://colab.research.google.com/github/kr7/DynamicROCKET/blob/main/DynamicROCKET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DynamicROCKET**
#
# This notebook contains the implementation related to the following study:
#
# K. Buza, M. Antal (2024): *ROCKET with dynamic convolution for time series classification*
#
# Please note that this implementation is **not optimized for run time**, but to illustrate the training and test process of ROCKET and DynamicROCKET.

# %%
import numpy as np
from numpy import random as rnd
from scipy.stats import ttest_rel
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import RidgeClassifier

# %%
# !wget http://www.timeseriesclassification.com/aeon-toolkit/Archives/Univariate2018_arff.zip
# Out:
# --2024-01-30 05:08:35--  http://www.timeseriesclassification.com/aeon-toolkit/Archives/Univariate2018_arff.zip
# Resolving www.timeseriesclassification.com (www.timeseriesclassification.com)... 109.123.71.232
# Connecting to www.timeseriesclassification.com (www.timeseriesclassification.com)|109.123.71.232|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 548832105 (523M) [application/zip]
# Saving to: ‘Univariate2018_arff.zip’
#
# Univariate2018_arff 100%[===================>] 523.41M  8.46MB/s    in 37s
#
# 2024-01-30 05:09:13 (14.2 MB/s) - ‘Univariate2018_arff.zip’ saved [548832105/548832105]

# %%
# !unzip Univariate2018_arff.zip
# Out:
# Archive:  Univariate2018_arff.zip
#    creating: Univariate_arff/
#    creating: Univariate_arff/ACSF1/
#   inflating: Univariate_arff/ACSF1/ACSF1.txt
#   inflating: Univariate_arff/ACSF1/ACSF1_TEST.arff
#   inflating: Univariate_arff/ACSF1/ACSF1_TEST.txt
#   inflating: Univariate_arff/ACSF1/ACSF1_TRAIN.arff
#   inflating: Univariate_arff/ACSF1/ACSF1_TRAIN.txt
#   inflating: Univariate_arff/ACSF1/README.md
#    creating: Univariate_arff/Adiac/
#   inflating: Univariate_arff/Adiac/Adiac.txt
#   inflating: Univariate_arff/Adiac/Adiac_TEST.arff
#   inflating: Univariate_arff/Adiac/Adiac_TEST.txt
#   inflating: Univariate_arff/Adiac/Adiac_TRAIN.arff
#   inflating: Univariate_arff/Adiac/Adiac_TRAIN.txt
#    creating: Univariate_arff/AllGestureWiimoteX/
#   inflating: Univariate_arff/AllGestureWiimoteX/AllGestureWiimoteX.txt
#   inflating: Univariate_arff/AllGestureWiimoteX/AllGestureWiimoteX_TEST.arff
#   inflating: Univariate_arff/AllGestureWiimoteX/AllGestureWiimoteX_TEST.txt
#   inflating: Univariate_arff/AllGestureWiimoteX/AllGestureWiimoteX_TRAIN.arff
#   inflating: Univariate_arff/AllGestureWiimoteX/AllGestureWiimoteX_TRAIN.txt
#   inflating: Univariate_arff/AllGestureWiimoteX/README.md
#    creating: Univariate_arff/AllGestureWiimoteY/
#   inflating: Univariate_arff/AllGestureWiimoteY/AllGestureWiimoteY.txt
#   inflating: Univariate_arff/AllGestureWiimoteY/AllGestureWiimoteY_TEST.arff
#   inflating: Univariate_arff/AllGestureWiimoteY/AllGestureWiimoteY_TEST.txt
#   inflating: Univariate_arff/AllGestureWiimoteY/AllGestureWiimoteY_TRAIN.arff
#   inflating: Univariate_arff/AllGestureWiimoteY/AllGestureWiimoteY_TRAIN.txt
#   inflating: Univariate_arff/AllGestureWiimoteY/README.md
#    creating: Univariate_arff/AllGestureWiimoteZ/
#   inflating: Univariate_arff/AllGestureWiimoteZ/AllGestureWiimoteZ.txt
#   inflating: Univariate_arff/AllGestureWiimoteZ/AllGestureWiimoteZ_TEST.arff
#   inflating: Univariate_arff/AllGestureWiimoteZ/AllGestureWiimoteZ_TEST.txt
#   inflating: Univariate_arff/AllGestureWiimoteZ/AllGestureWiimoteZ_TRAIN.arff
#   inflating: Univariate_arff/AllGestureWiimoteZ/AllGestureWiimoteZ_TRAIN.txt
#   inflating: Univariate_arff/AllGestureWiimoteZ/README.md
#    creating: Univariate_arff/ArrowHead/
#   inflating: Univariate_arff/ArrowHead/ArrowHead.txt
#   inflating: Univariate_arff/ArrowHead/ArrowHead_TEST.arff
#   inflating: Univariate_arff/ArrowHead/ArrowHead_TEST.txt
#   inflating: Univariate_arff/ArrowHead/ArrowHead_TRAIN.arff
#   inflating: Univariate_arff/ArrowHead/ArrowHead_TRAIN.txt
#    creating: Univariate_arff/Beef/
#   inflating: Univariate_arff/Beef/Beef.txt
#   inflating: Univariate_arff/Beef/Beef_TEST.arff
#   inflating: Univariate_arff/Beef/Beef_TEST.txt
#   inflating: Univariate_arff/Beef/Beef_TRAIN.arff
#   inflating: Univariate_arff/Beef/Beef_TRAIN.txt
#    creating: Univariate_arff/BeetleFly/
#   inflating: Univariate_arff/BeetleFly/BeetleFly.txt
#   inflating: Univariate_arff/BeetleFly/BeetleFly_TEST.arff
#   inflating: Univariate_arff/BeetleFly/BeetleFly_TEST.txt
#   inflating: Univariate_arff/BeetleFly/BeetleFly_TRAIN.arff
#   inflating: Univariate_arff/BeetleFly/BeetleFly_TRAIN.txt
#    creating: Univariate_arff/BirdChicken/
#   inflating: Univariate_arff/BirdChicken/BirdChicken.txt
#   inflating: Univariate_arff/BirdChicken/BirdChicken_TEST.arff
#   inflating: Univariate_arff/BirdChicken/BirdChicken_TEST.txt
#   inflating: Univariate_arff/BirdChicken/BirdChicken_TRAIN.arff
#   inflating: Univariate_arff/BirdChicken/BirdChicken_TRAIN.txt
#    creating: Univariate_arff/BME/
#   inflating: Univariate_arff/BME/BME.txt
#   inflating: Univariate_arff/BME/BME_TEST.arff
#   inflating: Univariate_arff/BME/BME_TEST.txt
#   inflating: Univariate_arff/BME/BME_TRAIN.arff
#   inflating: Univariate_arff/BME/BME_TRAIN.txt
#   inflating: Univariate_arff/BME/README.md
#    creating: Univariate_arff/Car/
#  extracting: Univariate_arff/Car/Car.txt
#   inflating: Univariate_arff/Car/Car_TEST.arff
#   inflating: Univariate_arff/Car/Car_TEST.txt
#   inflating: Univariate_arff/Car/Car_TRAIN.arff
#   inflating: Univariate_arff/Car/Car_TRAIN.txt
#    creating: Univariate_arff/CBF/
#   inflating: Univariate_arff/CBF/CBF.txt
#   inflating: Univariate_arff/CBF/CBF_TEST.arff
#   inflating: Univariate_arff/CBF/CBF_TEST.txt
#   inflating: Univariate_arff/CBF/CBF_TRAIN.arff
#   inflating: Univariate_arff/CBF/CBF_TRAIN.txt
#    creating: Univariate_arff/Chinatown/
#   inflating: Univariate_arff/Chinatown/Chinatown.txt
#   inflating: Univariate_arff/Chinatown/Chinatown_TEST.arff
#   inflating: Univariate_arff/Chinatown/Chinatown_TEST.txt
#   inflating: Univariate_arff/Chinatown/Chinatown_TRAIN.arff
#   inflating: Univariate_arff/Chinatown/Chinatown_TRAIN.txt
#   inflating: Univariate_arff/Chinatown/README.md
#    creating: Univariate_arff/ChlorineConcentration/
#   inflating: Univariate_arff/ChlorineConcentration/ChlorineConcentration.txt
#   inflating: Univariate_arff/ChlorineConcentration/ChlorineConcentration_TEST.arff
#   inflating: Univariate_arff/ChlorineConcentration/ChlorineConcentration_TEST.txt
#   inflating: Univariate_arff/ChlorineConcentration/ChlorineConcentration_TRAIN.arff
#   inflating: Univariate_arff/ChlorineConcentration/ChlorineConcentration_TRAIN.txt
#    creating: Univariate_arff/CinCECGTorso/
#   inflating: Univariate_arff/CinCECGTorso/CinCECGTorso.txt
#   inflating: Univariate_arff/CinCECGTorso/CinCECGTorso_TEST.arff
#   inflating: Univariate_arff/CinCECGTorso/CinCECGTorso_TEST.txt
#   inflating: Univariate_arff/CinCECGTorso/CinCECGTorso_TRAIN.arff
#   inflating: Univariate_arff/CinCECGTorso/CinCECGTorso_TRAIN.txt
#    creating: Univariate_arff/Coffee/
#   inflating: Univariate_arff/Coffee/Coffee.txt
#   inflating: Univariate_arff/Coffee/Coffee_TEST.arff
#   inflating: Univariate_arff/Coffee/Coffee_TEST.txt
#   inflating: Univariate_arff/Coffee/Coffee_TRAIN.arff
#   inflating: Univariate_arff/Coffee/Coffee_TRAIN.txt
#    creating: Univariate_arff/Computers/
#   inflating: Univariate_arff/Computers/Computers.txt
#   inflating: Univariate_arff/Computers/Computers_TEST.arff
#   inflating: Univariate_arff/Computers/Computers_TEST.txt
#   inflating: Univariate_arff/Computers/Computers_TRAIN.arff
#   inflating: Univariate_arff/Computers/Computers_TRAIN.txt
#    creating: Univariate_arff/CricketX/
#   inflating: Univariate_arff/CricketX/CricketX.txt
#   inflating: Univariate_arff/CricketX/CricketX_TEST.arff
#   inflating: Univariate_arff/CricketX/CricketX_TEST.txt
#   inflating: Univariate_arff/CricketX/CricketX_TRAIN.arff
#   inflating: Univariate_arff/CricketX/CricketX_TRAIN.txt
#    creating: Univariate_arff/CricketY/
#   inflating: Univariate_arff/CricketY/CricketY.txt
#   inflating: Univariate_arff/CricketY/CricketY_TEST.arff
#   inflating: Univariate_arff/CricketY/CricketY_TEST.txt
#   inflating: Univariate_arff/CricketY/CricketY_TRAIN.arff
#   inflating: Univariate_arff/CricketY/CricketY_TRAIN.txt
#    creating: Univariate_arff/CricketZ/
#   inflating: Univariate_arff/CricketZ/CricketZ.txt
#   inflating: Univariate_arff/CricketZ/CricketZ_TEST.arff
#   inflating: Univariate_arff/CricketZ/CricketZ_TEST.txt
#   inflating: Univariate_arff/CricketZ/CricketZ_TRAIN.arff
#   inflating: Univariate_arff/CricketZ/CricketZ_TRAIN.txt
#    creating: Univariate_arff/Crop/
#   inflating: Univariate_arff/Crop/Crop.txt
#   inflating: Univariate_arff/Crop/Crop_TEST.arff
#   inflating: Univariate_arff/Crop/Crop_TEST.txt
#   inflating: Univariate_arff/Crop/Crop_TRAIN.arff
#   inflating: Univariate_arff/Crop/Crop_TRAIN.txt
#   inflating: Univariate_arff/Crop/README.MD
#   inflating: Univariate_arff/dataset.csv
#   inflating: Univariate_arff/DataSummaryExpanded_NoMissingVals.xlsx
#   inflating: Univariate_arff/DataSummaryExpanded_v03.xlsx
#    creating: Univariate_arff/DiatomSizeReduction/
#  extracting: Univariate_arff/DiatomSizeReduction/DiatomSizeReduction.txt
#   inflating: Univariate_arff/DiatomSizeReduction/DiatomSizeReduction_TEST.arff
#   inflating: Univariate_arff/DiatomSizeReduction/DiatomSizeReduction_TEST.txt
#   inflating: Univariate_arff/DiatomSizeReduction/DiatomSizeReduction_TRAIN.arff
#   inflating: Univariate_arff/DiatomSizeReduction/DiatomSizeReduction_TRAIN.txt
#    creating: Univariate_arff/DistalPhalanxOutlineAgeGroup/
#   inflating: Univariate_arff/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup.txt
#   inflating: Univariate_arff/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup_TEST.arff
#   inflating: Univariate_arff/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup_TEST.txt
#   inflating: Univariate_arff/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup_TRAIN.arff
#   inflating: Univariate_arff/DistalPhalanxOutlineAgeGroup/DistalPhalanxOutlineAgeGroup_TRAIN.txt
#    creating: Univariate_arff/DistalPhalanxOutlineCorrect/
#   inflating: Univariate_arff/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect.txt
#   inflating: Univariate_arff/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect_TEST.arff
#   inflating: Univariate_arff/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect_TEST.txt
#   inflating: Univariate_arff/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect_TRAIN.arff
#   inflating: Univariate_arff/DistalPhalanxOutlineCorrect/DistalPhalanxOutlineCorrect_TRAIN.txt
#    creating: Univariate_arff/DistalPhalanxTW/
#   inflating: Univariate_arff/DistalPhalanxTW/DistalPhalanxTW.txt
#   inflating: Univariate_arff/DistalPhalanxTW/DistalPhalanxTW_TEST.arff
#   inflating: Univariate_arff/DistalPhalanxTW/DistalPhalanxTW_TEST.txt
#   inflating: Univariate_arff/DistalPhalanxTW/DistalPhalanxTW_TRAIN.arff
#   inflating: Univariate_arff/DistalPhalanxTW/DistalPhalanxTW_TRAIN.txt
#    creating: Univariate_arff/DodgerLoopDay/
#   inflating: Univariate_arff/DodgerLoopDay/DodgerLoopDay.txt
#   inflating: Univariate_arff/DodgerLoopDay/DodgerLoopDay_TEST.arff
#   inflating: Univariate_arff/DodgerLoopDay/DodgerLoopDay_TEST.txt
#   inflating: Univariate_arff/DodgerLoopDay/DodgerLoopDay_TRAIN.arff
#   inflating: Univariate_arff/DodgerLoopDay/DodgerLoopDay_TRAIN.txt
#   inflating: Univariate_arff/DodgerLoopDay/README.md
#    creating: Univariate_arff/DodgerLoopGame/
#   inflating: Univariate_arff/DodgerLoopGame/DodgerLoopGame.txt
#   inflating: Univariate_arff/DodgerLoopGame/DodgerLoopGame_TEST.arff
#   inflating: Univariate_arff/DodgerLoopGame/DodgerLoopGame_TEST.txt
#   inflating: Univariate_arff/DodgerLoopGame/DodgerLoopGame_TRAIN.arff
#   inflating: Univariate_arff/DodgerLoopGame/DodgerLoopGame_TRAIN.txt
#   inflating: Univariate_arff/DodgerLoopGame/README.md
#    creating: Univariate_arff/DodgerLoopWeekend/
#   inflating: Univariate_arff/DodgerLoopWeekend/DodgerLoopWeekend.txt
#   inflating: Univariate_arff/DodgerLoopWeekend/DodgerLoopWeekend_TEST.arff
#   inflating: Univariate_arff/DodgerLoopWeekend/DodgerLoopWeekend_TEST.txt
#   inflating: Univariate_arff/DodgerLoopWeekend/DodgerLoopWeekend_TRAIN.arff
#   inflating: Univariate_arff/DodgerLoopWeekend/DodgerLoopWeekend_TRAIN.txt
#   inflating: Univariate_arff/DodgerLoopWeekend/README.md
#    creating: Univariate_arff/Earthquakes/
#   inflating: Univariate_arff/Earthquakes/Earthquakes.txt
#   inflating: Univariate_arff/Earthquakes/Earthquakes_TEST.arff
#   inflating: Univariate_arff/Earthquakes/Earthquakes_TEST.txt
#   inflating: Univariate_arff/Earthquakes/Earthquakes_TRAIN.arff
#   inflating: Univariate_arff/Earthquakes/Earthquakes_TRAIN.txt
#    creating: Univariate_arff/ECG200/
#   inflating: Univariate_arff/ECG200/ECG200.txt
#   inflating: Univariate_arff/ECG200/ECG200_TEST.arff
#   inflating: Univariate_arff/ECG200/ECG200_TEST.txt
#   inflating: Univariate_arff/ECG200/ECG200_TRAIN.arff
#   inflating: Univariate_arff/ECG200/ECG200_TRAIN.txt
#    creating: Univariate_arff/ECG5000/
#  extracting: Univariate_arff/ECG5000/ECG5000.txt
#   inflating: Univariate_arff/ECG5000/ECG5000_TEST.arff
#   inflating: Univariate_arff/ECG5000/ECG5000_TEST.txt
#   inflating: Univariate_arff/ECG5000/ECG5000_TRAIN.arff
#   inflating: Univariate_arff/ECG5000/ECG5000_TRAIN.txt
#    creating: Univariate_arff/ECGFiveDays/
#   inflating: Univariate_arff/ECGFiveDays/ECGFiveDays.txt
#   inflating: Univariate_arff/ECGFiveDays/ECGFiveDays_TEST.arff
#   inflating: Univariate_arff/ECGFiveDays/ECGFiveDays_TEST.txt
#   inflating: Univariate_arff/ECGFiveDays/ECGFiveDays_TRAIN.arff
#   inflating: Univariate_arff/ECGFiveDays/ECGFiveDays_TRAIN.txt
#    creating: Univariate_arff/ElectricDevices/
#   inflating: Univariate_arff/ElectricDevices/ElectricDevices.txt
#   inflating: Univariate_arff/ElectricDevices/ElectricDevices_TEST.arff
#   inflating: Univariate_arff/ElectricDevices/ElectricDevices_TEST.txt
#   inflating: Univariate_arff/ElectricDevices/ElectricDevices_TRAIN.arff
#   inflating: Univariate_arff/ElectricDevices/ElectricDevices_TRAIN.txt
#    creating: Univariate_arff/EOGHorizontalSignal/
#   inflating: Univariate_arff/EOGHorizontalSignal/EOGHorizontalSignal.txt
#   inflating: Univariate_arff/EOGHorizontalSignal/EOGHorizontalSignal_TEST.arff
#   inflating: Univariate_arff/EOGHorizontalSignal/EOGHorizontalSignal_TEST.txt
#   inflating: Univariate_arff/EOGHorizontalSignal/EOGHorizontalSignal_TRAIN.arff
#   inflating: Univariate_arff/EOGHorizontalSignal/EOGHorizontalSignal_TRAIN.txt
#   inflating: Univariate_arff/EOGHorizontalSignal/README.md
#    creating: Univariate_arff/EOGVerticalSignal/
#   inflating: Univariate_arff/EOGVerticalSignal/EOGVerticalSignal.txt
#   inflating: Univariate_arff/EOGVerticalSignal/EOGVerticalSignal_TEST.arff
#   inflating: Univariate_arff/EOGVerticalSignal/EOGVerticalSignal_TEST.txt
#   inflating: Univariate_arff/EOGVerticalSignal/EOGVerticalSignal_TRAIN.arff
#   inflating: Univariate_arff/EOGVerticalSignal/EOGVerticalSignal_TRAIN.txt
#   inflating: Univariate_arff/EOGVerticalSignal/README.md
#    creating: Univariate_arff/EthanolLevel/
#   inflating: Univariate_arff/EthanolLevel/EthanolLevel.txt
#   inflating: Univariate_arff/EthanolLevel/EthanolLevel_TEST.arff
#   inflating: Univariate_arff/EthanolLevel/EthanolLevel_TEST.txt
#   inflating: Univariate_arff/EthanolLevel/EthanolLevel_TRAIN.arff
#   inflating: Univariate_arff/EthanolLevel/EthanolLevel_TRAIN.txt
#   inflating: Univariate_arff/EthanolLevel/README.md
#    creating: Univariate_arff/FaceAll/
#   inflating: Univariate_arff/FaceAll/FaceAll.txt
#   inflating: Univariate_arff/FaceAll/FaceAll_TEST.arff
#   inflating: Univariate_arff/FaceAll/FaceAll_TEST.txt
#   inflating: Univariate_arff/FaceAll/FaceAll_TRAIN.arff
#   inflating: Univariate_arff/FaceAll/FaceAll_TRAIN.txt
#    creating: Univariate_arff/FaceFour/
#  extracting: Univariate_arff/FaceFour/FaceFour.txt
#   inflating: Univariate_arff/FaceFour/FaceFour_TEST.arff
#   inflating: Univariate_arff/FaceFour/FaceFour_TEST.txt
#   inflating: Univariate_arff/FaceFour/FaceFour_TRAIN.arff
#   inflating: Univariate_arff/FaceFour/FaceFour_TRAIN.txt
#    creating: Univariate_arff/FacesUCR/
#  extracting: Univariate_arff/FacesUCR/FacesUCR.txt
#   inflating: Univariate_arff/FacesUCR/FacesUCR_TEST.arff
#   inflating: Univariate_arff/FacesUCR/FacesUCR_TEST.txt
#   inflating: Univariate_arff/FacesUCR/FacesUCR_TRAIN.arff
#   inflating: Univariate_arff/FacesUCR/FacesUCR_TRAIN.txt
#    creating: Univariate_arff/FiftyWords/
#   inflating: Univariate_arff/FiftyWords/FiftyWords.txt
#   inflating: Univariate_arff/FiftyWords/FiftyWords_TEST.arff
#   inflating: Univariate_arff/FiftyWords/FiftyWords_TEST.txt
#   inflating: Univariate_arff/FiftyWords/FiftyWords_TRAIN.arff
#   inflating: Univariate_arff/FiftyWords/FiftyWords_TRAIN.txt
#    creating: Univariate_arff/Fish/
#   inflating: Univariate_arff/Fish/Fish.txt
#   inflating: Univariate_arff/Fish/Fish_TEST.arff
#   inflating: Univariate_arff/Fish/Fish_TEST.txt
#   inflating: Univariate_arff/Fish/Fish_TRAIN.arff
#   inflating: Univariate_arff/Fish/Fish_TRAIN.txt
#    creating: Univariate_arff/FordA/
#   inflating: Univariate_arff/FordA/FordA.txt
#   inflating: Univariate_arff/FordA/FordA_TEST.arff
#   inflating: Univariate_arff/FordA/FordA_TEST.txt
#   inflating: Univariate_arff/FordA/FordA_TRAIN.arff
#   inflating: Univariate_arff/FordA/FordA_TRAIN.txt
#    creating: Univariate_arff/FordB/
#   inflating: Univariate_arff/FordB/FordB.txt
#   inflating: Univariate_arff/FordB/FordB_TEST.arff
#   inflating: Univariate_arff/FordB/FordB_TEST.txt
#   inflating: Univariate_arff/FordB/FordB_TRAIN.arff
#   inflating: Univariate_arff/FordB/FordB_TRAIN.txt
#    creating: Univariate_arff/FreezerRegularTrain/
#   inflating: Univariate_arff/FreezerRegularTrain/FreezerRegularTrain.txt
#   inflating: Univariate_arff/FreezerRegularTrain/FreezerRegularTrain_TEST.arff
#   inflating: Univariate_arff/FreezerRegularTrain/FreezerRegularTrain_TEST.txt
#   inflating: Univariate_arff/FreezerRegularTrain/FreezerRegularTrain_TRAIN.arff
#   inflating: Univariate_arff/FreezerRegularTrain/FreezerRegularTrain_TRAIN.txt
#   inflating: Univariate_arff/FreezerRegularTrain/README.md
#    creating: Univariate_arff/FreezerSmallTrain/
#   inflating: Univariate_arff/FreezerSmallTrain/FreezerSmallTrain.txt
#   inflating: Univariate_arff/FreezerSmallTrain/FreezerSmallTrain_TEST.arff
#   inflating: Univariate_arff/FreezerSmallTrain/FreezerSmallTrain_TEST.txt
#   inflating: Univariate_arff/FreezerSmallTrain/FreezerSmallTrain_TRAIN.arff
#   inflating: Univariate_arff/FreezerSmallTrain/FreezerSmallTrain_TRAIN.txt
#   inflating: Univariate_arff/FreezerSmallTrain/README.md
#    creating: Univariate_arff/Fungi/
#   inflating: Univariate_arff/Fungi/Fungi.txt
#   inflating: Univariate_arff/Fungi/Fungi_TEST.arff
#   inflating: Univariate_arff/Fungi/Fungi_TEST.txt
#   inflating: Univariate_arff/Fungi/Fungi_TRAIN.arff
#   inflating: Univariate_arff/Fungi/Fungi_TRAIN.txt
#   inflating: Univariate_arff/Fungi/README.md
#    creating: Univariate_arff/GestureMidAirD1/
#   inflating: Univariate_arff/GestureMidAirD1/GestureMidAirD1.txt
#   inflating: Univariate_arff/GestureMidAirD1/GestureMidAirD1_TEST.arff
#   inflating: Univariate_arff/GestureMidAirD1/GestureMidAirD1_TEST.txt
#   inflating: Univariate_arff/GestureMidAirD1/GestureMidAirD1_TRAIN.arff
#   inflating: Univariate_arff/GestureMidAirD1/GestureMidAirD1_TRAIN.txt
#   inflating: Univariate_arff/GestureMidAirD1/README.md
#    creating: Univariate_arff/GestureMidAirD2/
#   inflating: Univariate_arff/GestureMidAirD2/GestureMidAirD2.txt
#   inflating: Univariate_arff/GestureMidAirD2/GestureMidAirD2_TEST.arff
#   inflating: Univariate_arff/GestureMidAirD2/GestureMidAirD2_TEST.txt
#   inflating: Univariate_arff/GestureMidAirD2/GestureMidAirD2_TRAIN.arff
#   inflating: Univariate_arff/GestureMidAirD2/GestureMidAirD2_TRAIN.txt
#   inflating: Univariate_arff/GestureMidAirD2/README.md
#    creating: Univariate_arff/GestureMidAirD3/
#   inflating: Univariate_arff/GestureMidAirD3/GestureMidAirD3.txt
#   inflating: Univariate_arff/GestureMidAirD3/GestureMidAirD3_TEST.arff
#   inflating: Univariate_arff/GestureMidAirD3/GestureMidAirD3_TEST.txt
#   inflating: Univariate_arff/GestureMidAirD3/GestureMidAirD3_TRAIN.arff
#   inflating: Univariate_arff/GestureMidAirD3/GestureMidAirD3_TRAIN.txt
#   inflating: Univariate_arff/GestureMidAirD3/README.md
#    creating: Univariate_arff/GesturePebbleZ1/
#   inflating: Univariate_arff/GesturePebbleZ1/GesturePebbleZ1.txt
#   inflating: Univariate_arff/GesturePebbleZ1/GesturePebbleZ1_TEST.arff
#   inflating: Univariate_arff/GesturePebbleZ1/GesturePebbleZ1_TEST.txt
#   inflating: Univariate_arff/GesturePebbleZ1/GesturePebbleZ1_TRAIN.arff
#   inflating: Univariate_arff/GesturePebbleZ1/GesturePebbleZ1_TRAIN.txt
#   inflating: Univariate_arff/GesturePebbleZ1/README.md
#    creating: Univariate_arff/GesturePebbleZ2/
#   inflating: Univariate_arff/GesturePebbleZ2/GesturePebbleZ2.txt
#   inflating: Univariate_arff/GesturePebbleZ2/GesturePebbleZ2_TEST.arff
#   inflating: Univariate_arff/GesturePebbleZ2/GesturePebbleZ2_TEST.txt
#   inflating: Univariate_arff/GesturePebbleZ2/GesturePebbleZ2_TRAIN.arff
#   inflating: Univariate_arff/GesturePebbleZ2/GesturePebbleZ2_TRAIN.txt
#   inflating: Univariate_arff/GesturePebbleZ2/README.md
#    creating: Univariate_arff/GunPoint/
#    creating: Univariate_arff/GunPointAgeSpan/
#   inflating: Univariate_arff/GunPointAgeSpan/GunPointAgeSpan.txt
#   inflating: Univariate_arff/GunPointAgeSpan/GunPointAgeSpan_TEST.arff
#   inflating: Univariate_arff/GunPointAgeSpan/GunPointAgeSpan_TEST.txt
#   inflating: Univariate_arff/GunPointAgeSpan/GunPointAgeSpan_TRAIN.arff
#   inflating: Univariate_arff/GunPointAgeSpan/GunPointAgeSpan_TRAIN.txt
#   inflating: Univariate_arff/GunPointAgeSpan/README.md
#    creating: Univariate_arff/GunPointMaleVersusFemale/
#   inflating: Univariate_arff/GunPointMaleVersusFemale/GunPointMaleVersusFemale.txt
#   inflating: Univariate_arff/GunPointMaleVersusFemale/GunPointMaleVersusFemale_TEST.arff
#   inflating: Univariate_arff/GunPointMaleVersusFemale/GunPointMaleVersusFemale_TEST.txt
#   inflating: Univariate_arff/GunPointMaleVersusFemale/GunPointMaleVersusFemale_TRAIN.arff
#   inflating: Univariate_arff/GunPointMaleVersusFemale/GunPointMaleVersusFemale_TRAIN.txt
#   inflating: Univariate_arff/GunPointMaleVersusFemale/README.md
#    creating: Univariate_arff/GunPointOldVersusYoung/
#   inflating: Univariate_arff/GunPointOldVersusYoung/GunPointOldVersusYoung.txt
#   inflating: Univariate_arff/GunPointOldVersusYoung/GunPointOldVersusYoung_TEST.arff
#   inflating: Univariate_arff/GunPointOldVersusYoung/GunPointOldVersusYoung_TEST.txt
#   inflating: Univariate_arff/GunPointOldVersusYoung/GunPointOldVersusYoung_TRAIN.arff
#   inflating: Univariate_arff/GunPointOldVersusYoung/GunPointOldVersusYoung_TRAIN.txt
#   inflating: Univariate_arff/GunPointOldVersusYoung/README.md
#   inflating: Univariate_arff/GunPoint/GunPoint.txt
#   inflating: Univariate_arff/GunPoint/GunPoint_TEST.arff
#   inflating: Univariate_arff/GunPoint/GunPoint_TEST.txt
#   inflating: Univariate_arff/GunPoint/GunPoint_TRAIN.arff
#   inflating: Univariate_arff/GunPoint/GunPoint_TRAIN.txt
#    creating: Univariate_arff/Ham/
#   inflating: Univariate_arff/Ham/Ham.txt
#   inflating: Univariate_arff/Ham/Ham_TEST.arff
#   inflating: Univariate_arff/Ham/Ham_TEST.txt
#   inflating: Univariate_arff/Ham/Ham_TRAIN.arff
#   inflating: Univariate_arff/Ham/Ham_TRAIN.txt
#    creating: Univariate_arff/HandOutlines/
#   inflating: Univariate_arff/HandOutlines/HandOutlines.txt
#   inflating: Univariate_arff/HandOutlines/HandOutlines_TEST.arff
#   inflating: Univariate_arff/HandOutlines/HandOutlines_TEST.txt
#   inflating: Univariate_arff/HandOutlines/HandOutlines_TRAIN.arff
#   inflating: Univariate_arff/HandOutlines/HandOutlines_TRAIN.txt
#    creating: Univariate_arff/Haptics/
#   inflating: Univariate_arff/Haptics/Haptics.txt
#   inflating: Univariate_arff/Haptics/Haptics_TEST.arff
#   inflating: Univariate_arff/Haptics/Haptics_TEST.txt
#   inflating: Univariate_arff/Haptics/Haptics_TRAIN.arff
#   inflating: Univariate_arff/Haptics/Haptics_TRAIN.txt
#    creating: Univariate_arff/Herring/
#   inflating: Univariate_arff/Herring/Herring.txt
#   inflating: Univariate_arff/Herring/Herring_TEST.arff
#   inflating: Univariate_arff/Herring/Herring_TEST.txt
#   inflating: Univariate_arff/Herring/Herring_TRAIN.arff
#   inflating: Univariate_arff/Herring/Herring_TRAIN.txt
#    creating: Univariate_arff/HouseTwenty/
#   inflating: Univariate_arff/HouseTwenty/HouseTwenty.txt
#   inflating: Univariate_arff/HouseTwenty/HouseTwenty_TEST.arff
#   inflating: Univariate_arff/HouseTwenty/HouseTwenty_TEST.txt
#   inflating: Univariate_arff/HouseTwenty/HouseTwenty_TRAIN.arff
#   inflating: Univariate_arff/HouseTwenty/HouseTwenty_TRAIN.txt
#   inflating: Univariate_arff/HouseTwenty/README.md
#    creating: Univariate_arff/InlineSkate/
#   inflating: Univariate_arff/InlineSkate/InlineSkate.txt
#   inflating: Univariate_arff/InlineSkate/InlineSkate_TEST.arff
#   inflating: Univariate_arff/InlineSkate/InlineSkate_TEST.txt
#   inflating: Univariate_arff/InlineSkate/InlineSkate_TRAIN.arff
#   inflating: Univariate_arff/InlineSkate/InlineSkate_TRAIN.txt
#    creating: Univariate_arff/InsectEPGRegularTrain/
#   inflating: Univariate_arff/InsectEPGRegularTrain/InsectEPGRegularTrain.txt
#   inflating: Univariate_arff/InsectEPGRegularTrain/InsectEPGRegularTrain_TEST.arff
#   inflating: Univariate_arff/InsectEPGRegularTrain/InsectEPGRegularTrain_TEST.txt
#   inflating: Univariate_arff/InsectEPGRegularTrain/InsectEPGRegularTrain_TRAIN.arff
#   inflating: Univariate_arff/InsectEPGRegularTrain/InsectEPGRegularTrain_TRAIN.txt
#   inflating: Univariate_arff/InsectEPGRegularTrain/README.md
#    creating: Univariate_arff/InsectEPGSmallTrain/
#   inflating: Univariate_arff/InsectEPGSmallTrain/InsectEPGSmallTrain.txt
#   inflating: Univariate_arff/InsectEPGSmallTrain/InsectEPGSmallTrain_TEST.arff
#   inflating: Univariate_arff/InsectEPGSmallTrain/InsectEPGSmallTrain_TEST.txt
#   inflating: Univariate_arff/InsectEPGSmallTrain/InsectEPGSmallTrain_TRAIN.arff
#   inflating: Univariate_arff/InsectEPGSmallTrain/InsectEPGSmallTrain_TRAIN.txt
#   inflating: Univariate_arff/InsectEPGSmallTrain/README.md
#    creating: Univariate_arff/InsectWingbeatSound/
#   inflating: Univariate_arff/InsectWingbeatSound/InsectWingbeatSound.txt
#   inflating: Univariate_arff/InsectWingbeatSound/InsectWingbeatSound_TEST.arff
#   inflating: Univariate_arff/InsectWingbeatSound/InsectWingbeatSound_TEST.txt
#   inflating: Univariate_arff/InsectWingbeatSound/InsectWingbeatSound_TRAIN.arff
#   inflating: Univariate_arff/InsectWingbeatSound/InsectWingbeatSound_TRAIN.txt
#    creating: Univariate_arff/ItalyPowerDemand/
#   inflating: Univariate_arff/ItalyPowerDemand/ItalyPowerDemand.txt
#   inflating: Univariate_arff/ItalyPowerDemand/ItalyPowerDemand_TEST.arff
#   inflating: Univariate_arff/ItalyPowerDemand/ItalyPowerDemand_TEST.txt
#   inflating: Univariate_arff/ItalyPowerDemand/ItalyPowerDemand_TRAIN.arff
#   inflating: Univariate_arff/ItalyPowerDemand/ItalyPowerDemand_TRAIN.txt
#    creating: Univariate_arff/LargeKitchenAppliances/
#   inflating: Univariate_arff/LargeKitchenAppliances/LargeKitchenAppliances.txt
#   inflating: Univariate_arff/LargeKitchenAppliances/LargeKitchenAppliances_TEST.arff
#   inflating: Univariate_arff/LargeKitchenAppliances/LargeKitchenAppliances_TEST.txt
#   inflating: Univariate_arff/LargeKitchenAppliances/LargeKitchenAppliances_TRAIN.arff
#   inflating: Univariate_arff/LargeKitchenAppliances/LargeKitchenAppliances_TRAIN.txt
#    creating: Univariate_arff/Lightning2/
#   inflating: Univariate_arff/Lightning2/Lightning2.txt
#   inflating: Univariate_arff/Lightning2/Lightning2_TEST.arff
#   inflating: Univariate_arff/Lightning2/Lightning2_TEST.txt
#   inflating: Univariate_arff/Lightning2/Lightning2_TRAIN.arff
#   inflating: Univariate_arff/Lightning2/Lightning2_TRAIN.txt
#    creating: Univariate_arff/Lightning7/
#  extracting: Univariate_arff/Lightning7/Lightning7.txt
#   inflating: Univariate_arff/Lightning7/Lightning7_TEST.arff
#   inflating: Univariate_arff/Lightning7/Lightning7_TEST.txt
#   inflating: Univariate_arff/Lightning7/Lightning7_TRAIN.arff
#   inflating: Univariate_arff/Lightning7/Lightning7_TRAIN.txt
#    creating: Univariate_arff/Mallat/
#   inflating: Univariate_arff/Mallat/Mallat.txt
#   inflating: Univariate_arff/Mallat/Mallat_TEST.arff
#   inflating: Univariate_arff/Mallat/Mallat_TEST.txt
#   inflating: Univariate_arff/Mallat/Mallat_TRAIN.arff
#   inflating: Univariate_arff/Mallat/Mallat_TRAIN.txt
#    creating: Univariate_arff/Meat/
#   inflating: Univariate_arff/Meat/Meat.txt
#   inflating: Univariate_arff/Meat/Meat_TEST.arff
#   inflating: Univariate_arff/Meat/Meat_TEST.txt
#   inflating: Univariate_arff/Meat/Meat_TRAIN.arff
#   inflating: Univariate_arff/Meat/Meat_TRAIN.txt
#    creating: Univariate_arff/MedicalImages/
#   inflating: Univariate_arff/MedicalImages/MedicalImages.txt
#   inflating: Univariate_arff/MedicalImages/MedicalImages_TEST.arff
#   inflating: Univariate_arff/MedicalImages/MedicalImages_TEST.txt
#   inflating: Univariate_arff/MedicalImages/MedicalImages_TRAIN.arff
#   inflating: Univariate_arff/MedicalImages/MedicalImages_TRAIN.txt
#    creating: Univariate_arff/MelbournePedestrian/
#   inflating: Univariate_arff/MelbournePedestrian/MelbournePedestrian.txt
#   inflating: Univariate_arff/MelbournePedestrian/MelbournePedestrian_TEST.arff
#   inflating: Univariate_arff/MelbournePedestrian/MelbournePedestrian_TEST.csv
#   inflating: Univariate_arff/MelbournePedestrian/MelbournePedestrian_TEST.txt
#   inflating: Univariate_arff/MelbournePedestrian/MelbournePedestrian_TRAIN.arff
#   inflating: Univariate_arff/MelbournePedestrian/MelbournePedestrian_TRAIN.txt
#   inflating: Univariate_arff/MelbournePedestrian/README.md
#    creating: Univariate_arff/MiddlePhalanxOutlineAgeGroup/
#   inflating: Univariate_arff/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup.txt
#   inflating: Univariate_arff/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TEST.arff
#   inflating: Univariate_arff/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TEST.txt
#   inflating: Univariate_arff/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TRAIN.arff
#   inflating: Univariate_arff/MiddlePhalanxOutlineAgeGroup/MiddlePhalanxOutlineAgeGroup_TRAIN.txt
#    creating: Univariate_arff/MiddlePhalanxOutlineCorrect/
#   inflating: Univariate_arff/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect.txt
#   inflating: Univariate_arff/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TEST.arff
#   inflating: Univariate_arff/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TEST.txt
#   inflating: Univariate_arff/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TRAIN.arff
#   inflating: Univariate_arff/MiddlePhalanxOutlineCorrect/MiddlePhalanxOutlineCorrect_TRAIN.txt
#    creating: Univariate_arff/MiddlePhalanxTW/
#   inflating: Univariate_arff/MiddlePhalanxTW/MiddlePhalanxTW.txt
#   inflating: Univariate_arff/MiddlePhalanxTW/MiddlePhalanxTW_TEST.arff
#   inflating: Univariate_arff/MiddlePhalanxTW/MiddlePhalanxTW_TEST.txt
#   inflating: Univariate_arff/MiddlePhalanxTW/MiddlePhalanxTW_TRAIN.arff
#   inflating: Univariate_arff/MiddlePhalanxTW/MiddlePhalanxTW_TRAIN.txt
#    creating: Univariate_arff/MixedShapesRegularTrain/
#   inflating: Univariate_arff/MixedShapesRegularTrain/MixedShapesRegularTrain.txt
#   inflating: Univariate_arff/MixedShapesRegularTrain/MixedShapesRegularTrain_TEST.arff
#   inflating: Univariate_arff/MixedShapesRegularTrain/MixedShapesRegularTrain_TEST.txt
#   inflating: Univariate_arff/MixedShapesRegularTrain/MixedShapesRegularTrain_TRAIN.arff
#   inflating: Univariate_arff/MixedShapesRegularTrain/MixedShapesRegularTrain_TRAIN.txt
#   inflating: Univariate_arff/MixedShapesRegularTrain/README.md
#    creating: Univariate_arff/MixedShapesSmallTrain/
#   inflating: Univariate_arff/MixedShapesSmallTrain/MixedShapesSmallTrain.txt
#   inflating: Univariate_arff/MixedShapesSmallTrain/MixedShapesSmallTrain_TEST.arff
#   inflating: Univariate_arff/MixedShapesSmallTrain/MixedShapesSmallTrain_TEST.txt
#   inflating: Univariate_arff/MixedShapesSmallTrain/MixedShapesSmallTrain_TRAIN.arff
#   inflating: Univariate_arff/MixedShapesSmallTrain/MixedShapesSmallTrain_TRAIN.txt
#   inflating: Univariate_arff/MixedShapesSmallTrain/README.md
#    creating: Univariate_arff/MoteStrain/
#   inflating: Univariate_arff/MoteStrain/MoteStrain.txt
#   inflating: Univariate_arff/MoteStrain/MoteStrain_TEST.arff
#   inflating: Univariate_arff/MoteStrain/MoteStrain_TEST.txt
#   inflating: Univariate_arff/MoteStrain/MoteStrain_TRAIN.arff
#   inflating: Univariate_arff/MoteStrain/MoteStrain_TRAIN.txt
#   inflating: Univariate_arff/newProblemsUpload.csv
#    creating: Univariate_arff/NonInvasiveFetalECGThorax1/
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1.txt
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1_TEST.arff
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1_TEST.txt
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1_TRAIN.arff
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax1/NonInvasiveFetalECGThorax1_TRAIN.txt
#    creating: Univariate_arff/NonInvasiveFetalECGThorax2/
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2.txt
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2_TEST.arff
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2_TEST.txt
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2_TRAIN.arff
#   inflating: Univariate_arff/NonInvasiveFetalECGThorax2/NonInvasiveFetalECGThorax2_TRAIN.txt
#    creating: Univariate_arff/OliveOil/
#   inflating: Univariate_arff/OliveOil/OliveOil.txt
#   inflating: Univariate_arff/OliveOil/OliveOil_TEST.arff
#   inflating: Univariate_arff/OliveOil/OliveOil_TEST.txt
#   inflating: Univariate_arff/OliveOil/OliveOil_TRAIN.arff
#   inflating: Univariate_arff/OliveOil/OliveOil_TRAIN.txt
#    creating: Univariate_arff/OSULeaf/
#   inflating: Univariate_arff/OSULeaf/OSULeaf.txt
#   inflating: Univariate_arff/OSULeaf/OSULeaf_TEST.arff
#   inflating: Univariate_arff/OSULeaf/OSULeaf_TEST.txt
#   inflating: Univariate_arff/OSULeaf/OSULeaf_TRAIN.arff
#   inflating: Univariate_arff/OSULeaf/OSULeaf_TRAIN.txt
#    creating: Univariate_arff/PhalangesOutlinesCorrect/
#   inflating: Univariate_arff/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect.txt
#   inflating: Univariate_arff/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TEST.arff
#   inflating: Univariate_arff/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TEST.txt
#   inflating: Univariate_arff/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TRAIN.arff
#   inflating: Univariate_arff/PhalangesOutlinesCorrect/PhalangesOutlinesCorrect_TRAIN.txt
#    creating: Univariate_arff/Phoneme/
#   inflating: Univariate_arff/Phoneme/Phoneme.txt
#   inflating: Univariate_arff/Phoneme/Phoneme_TEST.arff
#   inflating: Univariate_arff/Phoneme/Phoneme_TEST.txt
#   inflating: Univariate_arff/Phoneme/Phoneme_TRAIN.arff
#   inflating: Univariate_arff/Phoneme/Phoneme_TRAIN.txt
#    creating: Univariate_arff/PickupGestureWiimoteZ/
#   inflating: Univariate_arff/PickupGestureWiimoteZ/PickupGestureWiimoteZ.txt
#   inflating: Univariate_arff/PickupGestureWiimoteZ/PickupGestureWiimoteZ_TEST.arff
#   inflating: Univariate_arff/PickupGestureWiimoteZ/PickupGestureWiimoteZ_TEST.txt
#   inflating: Univariate_arff/PickupGestureWiimoteZ/PickupGestureWiimoteZ_TRAIN.arff
#   inflating: Univariate_arff/PickupGestureWiimoteZ/PickupGestureWiimoteZ_TRAIN.txt
#   inflating: Univariate_arff/PickupGestureWiimoteZ/README.md
#    creating: Univariate_arff/Pictures/
#    creating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg.zip
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/ACSF1.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/AllGestureWiimoteX.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/AllGestureWiimoteY.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/AllGestureWiimoteZ.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/BME.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/Chinatown.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/Crop.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/DodgerLoopDay.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/DodgerLoopGame.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/DodgerLoopWeekend.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/EOGHorizontalSignal.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/EOGVertialSignal.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/EthanolLevel.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/FreezerRegularTrain.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/FreezerSmallTrain.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/Fungi.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GestureMidAirD1.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GestureMidAirD2.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GestureMidAirD3.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GesturePebbleZ1.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GesturePebbleZ2.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GunPointAgeSpan.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GunPointMaleVersusFemale.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/GunPointOldVersusYoung.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/HouseTwenty.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/InsectEPGRegularTrain.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/InsectEPGSmallTrain.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/MelbournePedestrian.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/MixedShapesRegularTrain.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/MixedShapesSmallTrain.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/PickupGestureWiimoteZ.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/PigAirwayPressure.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/PigArtPressure.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/PigCVP.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/PLAID.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/PowerCons.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/Rock.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/SemgHandGenderCh2.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/SemgHandMovementCh2.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/SemgHandSubjectCh2.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/ShakeGestureWiimoteZ.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/SmoothSubspace.jpg
#   inflating: Univariate_arff/Pictures/fall_2018_datasets_crop_jpg/UMD.jpg
#    creating: Univariate_arff/PigAirwayPressure/
#   inflating: Univariate_arff/PigAirwayPressure/PigAirwayPressure.txt
#   inflating: Univariate_arff/PigAirwayPressure/PigAirwayPressure_TEST.arff
#   inflating: Univariate_arff/PigAirwayPressure/PigAirwayPressure_TEST.txt
#   inflating: Univariate_arff/PigAirwayPressure/PigAirwayPressure_TRAIN.arff
#   inflating: Univariate_arff/PigAirwayPressure/PigAirwayPressure_TRAIN.txt
#   inflating: Univariate_arff/PigAirwayPressure/README.md
#    creating: Univariate_arff/PigArtPressure/
#   inflating: Univariate_arff/PigArtPressure/PigArtPressure.txt
#   inflating: Univariate_arff/PigArtPressure/PigArtPressure_TEST.arff
#   inflating: Univariate_arff/PigArtPressure/PigArtPressure_TEST.txt
#   inflating: Univariate_arff/PigArtPressure/PigArtPressure_TRAIN.arff
#   inflating: Univariate_arff/PigArtPressure/PigArtPressure_TRAIN.txt
#   inflating: Univariate_arff/PigArtPressure/README.md
#    creating: Univariate_arff/PigCVP/
#   inflating: Univariate_arff/PigCVP/PigCVP.txt
#   inflating: Univariate_arff/PigCVP/PigCVP_TEST.arff
#   inflating: Univariate_arff/PigCVP/PigCVP_TEST.txt
#   inflating: Univariate_arff/PigCVP/PigCVP_TRAIN.arff
#   inflating: Univariate_arff/PigCVP/PigCVP_TRAIN.txt
#   inflating: Univariate_arff/PigCVP/README.md
#    creating: Univariate_arff/PLAID/
#   inflating: Univariate_arff/PLAID/PLAID.txt
#   inflating: Univariate_arff/PLAID/PLAID_TEST.arff
#   inflating: Univariate_arff/PLAID/PLAID_TEST.txt
#   inflating: Univariate_arff/PLAID/PLAID_TRAIN.arff
#   inflating: Univariate_arff/PLAID/PLAID_TRAIN.txt
#   inflating: Univariate_arff/PLAID/README.md
#    creating: Univariate_arff/Plane/
#  extracting: Univariate_arff/Plane/Plane.txt
#   inflating: Univariate_arff/Plane/Plane_TEST.arff
#   inflating: Univariate_arff/Plane/Plane_TEST.txt
#   inflating: Univariate_arff/Plane/Plane_TRAIN.arff
#   inflating: Univariate_arff/Plane/Plane_TRAIN.txt
#    creating: Univariate_arff/PowerCons/
#   inflating: Univariate_arff/PowerCons/PowerCons.txt
#   inflating: Univariate_arff/PowerCons/PowerCons_TEST.arff
#   inflating: Univariate_arff/PowerCons/PowerCons_TEST.txt
#   inflating: Univariate_arff/PowerCons/PowerCons_TRAIN.arff
#   inflating: Univariate_arff/PowerCons/PowerCons_TRAIN.txt
#   inflating: Univariate_arff/PowerCons/README.md
#    creating: Univariate_arff/ProximalPhalanxOutlineAgeGroup/
#   inflating: Univariate_arff/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup.txt
#   inflating: Univariate_arff/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TEST.arff
#   inflating: Univariate_arff/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TEST.txt
#   inflating: Univariate_arff/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TRAIN.arff
#   inflating: Univariate_arff/ProximalPhalanxOutlineAgeGroup/ProximalPhalanxOutlineAgeGroup_TRAIN.txt
#    creating: Univariate_arff/ProximalPhalanxOutlineCorrect/
#   inflating: Univariate_arff/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect.txt
#   inflating: Univariate_arff/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TEST.arff
#   inflating: Univariate_arff/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TEST.txt
#   inflating: Univariate_arff/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TRAIN.arff
#   inflating: Univariate_arff/ProximalPhalanxOutlineCorrect/ProximalPhalanxOutlineCorrect_TRAIN.txt
#    creating: Univariate_arff/ProximalPhalanxTW/
#   inflating: Univariate_arff/ProximalPhalanxTW/ProximalPhalanxTW.txt
#   inflating: Univariate_arff/ProximalPhalanxTW/ProximalPhalanxTW_TEST.arff
#   inflating: Univariate_arff/ProximalPhalanxTW/ProximalPhalanxTW_TEST.txt
#   inflating: Univariate_arff/ProximalPhalanxTW/ProximalPhalanxTW_TRAIN.arff
#   inflating: Univariate_arff/ProximalPhalanxTW/ProximalPhalanxTW_TRAIN.txt
#    creating: Univariate_arff/RefrigerationDevices/
#   inflating: Univariate_arff/RefrigerationDevices/RefrigerationDevices.txt
#   inflating: Univariate_arff/RefrigerationDevices/RefrigerationDevices_TEST.arff
#   inflating: Univariate_arff/RefrigerationDevices/RefrigerationDevices_TEST.txt
#   inflating: Univariate_arff/RefrigerationDevices/RefrigerationDevices_TRAIN.arff
#   inflating: Univariate_arff/RefrigerationDevices/RefrigerationDevices_TRAIN.txt
#    creating: Univariate_arff/Rock/
#   inflating: Univariate_arff/Rock/README.md
#   inflating: Univariate_arff/Rock/Rock.txt
#   inflating: Univariate_arff/Rock/Rock_TEST.arff
#   inflating: Univariate_arff/Rock/Rock_TEST.txt
#   inflating: Univariate_arff/Rock/Rock_TRAIN.arff
#   inflating: Univariate_arff/Rock/Rock_TRAIN.txt
#    creating: Univariate_arff/ScreenType/
#   inflating: Univariate_arff/ScreenType/ScreenType.txt
#   inflating: Univariate_arff/ScreenType/ScreenType_TEST.arff
#   inflating: Univariate_arff/ScreenType/ScreenType_TEST.txt
#   inflating: Univariate_arff/ScreenType/ScreenType_TRAIN.arff
#   inflating: Univariate_arff/ScreenType/ScreenType_TRAIN.txt
#    creating: Univariate_arff/SemgHandGenderCh2/
#   inflating: Univariate_arff/SemgHandGenderCh2/README.md
#   inflating: Univariate_arff/SemgHandGenderCh2/SemgHandGenderCh2.txt
#   inflating: Univariate_arff/SemgHandGenderCh2/SemgHandGenderCh2_TEST.arff
#   inflating: Univariate_arff/SemgHandGenderCh2/SemgHandGenderCh2_TEST.txt
#   inflating: Univariate_arff/SemgHandGenderCh2/SemgHandGenderCh2_TRAIN.arff
#   inflating: Univariate_arff/SemgHandGenderCh2/SemgHandGenderCh2_TRAIN.txt
#    creating: Univariate_arff/SemgHandMovementCh2/
#   inflating: Univariate_arff/SemgHandMovementCh2/README.md
#   inflating: Univariate_arff/SemgHandMovementCh2/SemgHandMovementCh2.txt
#   inflating: Univariate_arff/SemgHandMovementCh2/SemgHandMovementCh2_TEST.arff
#   inflating: Univariate_arff/SemgHandMovementCh2/SemgHandMovementCh2_TEST.txt
#   inflating: Univariate_arff/SemgHandMovementCh2/SemgHandMovementCh2_TRAIN.arff
#   inflating: Univariate_arff/SemgHandMovementCh2/SemgHandMovementCh2_TRAIN.txt
#    creating: Univariate_arff/SemgHandSubjectCh2/
#   inflating: Univariate_arff/SemgHandSubjectCh2/README.md
#   inflating: Univariate_arff/SemgHandSubjectCh2/SemgHandSubjectCh2.txt
#   inflating: Univariate_arff/SemgHandSubjectCh2/SemgHandSubjectCh2_TEST.arff
#   inflating: Univariate_arff/SemgHandSubjectCh2/SemgHandSubjectCh2_TEST.txt
#   inflating: Univariate_arff/SemgHandSubjectCh2/SemgHandSubjectCh2_TRAIN.arff
#   inflating: Univariate_arff/SemgHandSubjectCh2/SemgHandSubjectCh2_TRAIN.txt
#    creating: Univariate_arff/ShakeGestureWiimoteZ/
#   inflating: Univariate_arff/ShakeGestureWiimoteZ/README.md
#   inflating: Univariate_arff/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ.txt
#   inflating: Univariate_arff/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ_TEST.arff
#   inflating: Univariate_arff/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ_TEST.txt
#   inflating: Univariate_arff/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ_TRAIN.arff
#   inflating: Univariate_arff/ShakeGestureWiimoteZ/ShakeGestureWiimoteZ_TRAIN.txt
#    creating: Univariate_arff/ShapeletSim/
#   inflating: Univariate_arff/ShapeletSim/ShapeletSim.txt
#   inflating: Univariate_arff/ShapeletSim/ShapeletSim_TEST.arff
#   inflating: Univariate_arff/ShapeletSim/ShapeletSim_TEST.txt
#   inflating: Univariate_arff/ShapeletSim/ShapeletSim_TRAIN.arff
#   inflating: Univariate_arff/ShapeletSim/ShapeletSim_TRAIN.txt
#    creating: Univariate_arff/ShapesAll/
#   inflating: Univariate_arff/ShapesAll/ShapesAll.txt
#   inflating: Univariate_arff/ShapesAll/ShapesAll_TEST.arff
#   inflating: Univariate_arff/ShapesAll/ShapesAll_TEST.txt
#   inflating: Univariate_arff/ShapesAll/ShapesAll_TRAIN.arff
#   inflating: Univariate_arff/ShapesAll/ShapesAll_TRAIN.txt
#    creating: Univariate_arff/SmallKitchenAppliances/
#   inflating: Univariate_arff/SmallKitchenAppliances/SmallKitchenAppliances.txt
#   inflating: Univariate_arff/SmallKitchenAppliances/SmallKitchenAppliances_TEST.arff
#   inflating: Univariate_arff/SmallKitchenAppliances/SmallKitchenAppliances_TEST.txt
#   inflating: Univariate_arff/SmallKitchenAppliances/SmallKitchenAppliances_TRAIN.arff
#   inflating: Univariate_arff/SmallKitchenAppliances/SmallKitchenAppliances_TRAIN.txt
#    creating: Univariate_arff/SmoothSubspace/
#   inflating: Univariate_arff/SmoothSubspace/README.md
#   inflating: Univariate_arff/SmoothSubspace/SmoothSubspace.txt
#   inflating: Univariate_arff/SmoothSubspace/SmoothSubspace_TEST.arff
#   inflating: Univariate_arff/SmoothSubspace/SmoothSubspace_TEST.txt
#   inflating: Univariate_arff/SmoothSubspace/SmoothSubspace_TRAIN.arff
#   inflating: Univariate_arff/SmoothSubspace/SmoothSubspace_TRAIN.txt
#    creating: Univariate_arff/SonyAIBORobotSurface1/
#   inflating: Univariate_arff/SonyAIBORobotSurface1/SonyAIBORobotSurface1.txt
#   inflating: Univariate_arff/SonyAIBORobotSurface1/SonyAIBORobotSurface1_TEST.arff
#   inflating: Univariate_arff/SonyAIBORobotSurface1/SonyAIBORobotSurface1_TEST.txt
#   inflating: Univariate_arff/SonyAIBORobotSurface1/SonyAIBORobotSurface1_TRAIN.arff
#   inflating: Univariate_arff/SonyAIBORobotSurface1/SonyAIBORobotSurface1_TRAIN.txt
#    creating: Univariate_arff/SonyAIBORobotSurface2/
#  extracting: Univariate_arff/SonyAIBORobotSurface2/SonyAIBORobotSurface2.txt
#   inflating: Univariate_arff/SonyAIBORobotSurface2/SonyAIBORobotSurface2_TEST.arff
#   inflating: Univariate_arff/SonyAIBORobotSurface2/SonyAIBORobotSurface2_TEST.txt
#   inflating: Univariate_arff/SonyAIBORobotSurface2/SonyAIBORobotSurface2_TRAIN.arff
#   inflating: Univariate_arff/SonyAIBORobotSurface2/SonyAIBORobotSurface2_TRAIN.txt
#    creating: Univariate_arff/StarLightCurves/
#   inflating: Univariate_arff/StarLightCurves/StarLightCurves.txt
#   inflating: Univariate_arff/StarLightCurves/StarLightCurves_TEST.arff
#   inflating: Univariate_arff/StarLightCurves/StarLightCurves_TEST.txt
#   inflating: Univariate_arff/StarLightCurves/StarLightCurves_TRAIN.arff
#   inflating: Univariate_arff/StarLightCurves/StarLightCurves_TRAIN.txt
#    creating: Univariate_arff/Strawberry/
#   inflating: Univariate_arff/Strawberry/Strawberry.txt
#   inflating: Univariate_arff/Strawberry/Strawberry_TEST.arff
#   inflating: Univariate_arff/Strawberry/Strawberry_TEST.txt
#   inflating: Univariate_arff/Strawberry/Strawberry_TRAIN.arff
#   inflating: Univariate_arff/Strawberry/Strawberry_TRAIN.txt
#   inflating: Univariate_arff/SummaryData.csv
#    creating: Univariate_arff/SwedishLeaf/
#   inflating: Univariate_arff/SwedishLeaf/SwedishLeaf.txt
#   inflating: Univariate_arff/SwedishLeaf/SwedishLeaf_TEST.arff
#   inflating: Univariate_arff/SwedishLeaf/SwedishLeaf_TEST.txt
#   inflating: Univariate_arff/SwedishLeaf/SwedishLeaf_TRAIN.arff
#   inflating: Univariate_arff/SwedishLeaf/SwedishLeaf_TRAIN.txt
#    creating: Univariate_arff/Symbols/
#   inflating: Univariate_arff/Symbols/Symbols.txt
#   inflating: Univariate_arff/Symbols/Symbols_TEST.arff
#   inflating: Univariate_arff/Symbols/Symbols_TEST.txt
#   inflating: Univariate_arff/Symbols/Symbols_TRAIN.arff
#   inflating: Univariate_arff/Symbols/Symbols_TRAIN.txt
#    creating: Univariate_arff/SyntheticControl/
#   inflating: Univariate_arff/SyntheticControl/SyntheticControl.txt
#   inflating: Univariate_arff/SyntheticControl/SyntheticControl_TEST.arff
#   inflating: Univariate_arff/SyntheticControl/SyntheticControl_TEST.txt
#   inflating: Univariate_arff/SyntheticControl/SyntheticControl_TRAIN.arff
#   inflating: Univariate_arff/SyntheticControl/SyntheticControl_TRAIN.txt
#    creating: Univariate_arff/ToeSegmentation1/
#   inflating: Univariate_arff/ToeSegmentation1/ToeSegmentation1.txt
#   inflating: Univariate_arff/ToeSegmentation1/ToeSegmentation1_TEST.arff
#   inflating: Univariate_arff/ToeSegmentation1/ToeSegmentation1_TEST.txt
#   inflating: Univariate_arff/ToeSegmentation1/ToeSegmentation1_TRAIN.arff
#   inflating: Univariate_arff/ToeSegmentation1/ToeSegmentation1_TRAIN.txt
#    creating: Univariate_arff/ToeSegmentation2/
#   inflating: Univariate_arff/ToeSegmentation2/ToeSegmentation2.txt
#   inflating: Univariate_arff/ToeSegmentation2/ToeSegmentation2_TEST.arff
#   inflating: Univariate_arff/ToeSegmentation2/ToeSegmentation2_TEST.txt
#   inflating: Univariate_arff/ToeSegmentation2/ToeSegmentation2_TRAIN.arff
#   inflating: Univariate_arff/ToeSegmentation2/ToeSegmentation2_TRAIN.txt
#    creating: Univariate_arff/Trace/
#   inflating: Univariate_arff/Trace/Trace.txt
#   inflating: Univariate_arff/Trace/Trace_TEST.arff
#   inflating: Univariate_arff/Trace/Trace_TEST.txt
#   inflating: Univariate_arff/Trace/Trace_TRAIN.arff
#   inflating: Univariate_arff/Trace/Trace_TRAIN.txt
#   inflating: Univariate_arff/TwoClassProblems.csv
#    creating: Univariate_arff/TwoLeadECG/
#   inflating: Univariate_arff/TwoLeadECG/TwoLeadECG.txt
#   inflating: Univariate_arff/TwoLeadECG/TwoLeadECG_TEST.arff
#   inflating: Univariate_arff/TwoLeadECG/TwoLeadECG_TEST.txt
#   inflating: Univariate_arff/TwoLeadECG/TwoLeadECG_TRAIN.arff
#   inflating: Univariate_arff/TwoLeadECG/TwoLeadECG_TRAIN.txt
#    creating: Univariate_arff/TwoPatterns/
#   inflating: Univariate_arff/TwoPatterns/TwoPatterns.txt
#   inflating: Univariate_arff/TwoPatterns/TwoPatterns_TEST.arff
#   inflating: Univariate_arff/TwoPatterns/TwoPatterns_TEST.txt
#   inflating: Univariate_arff/TwoPatterns/TwoPatterns_TRAIN.arff
#   inflating: Univariate_arff/TwoPatterns/TwoPatterns_TRAIN.txt
#    creating: Univariate_arff/UMD/
#   inflating: Univariate_arff/UMD/README.md
#   inflating: Univariate_arff/UMD/UMD.txt
#   inflating: Univariate_arff/UMD/UMD_TEST.arff
#   inflating: Univariate_arff/UMD/UMD_TEST.txt
#   inflating: Univariate_arff/UMD/UMD_TRAIN.arff
#   inflating: Univariate_arff/UMD/UMD_TRAIN.txt
#    creating: Univariate_arff/UWaveGestureLibraryAll/
#   inflating: Univariate_arff/UWaveGestureLibraryAll/UWaveGestureLibraryAll.txt
#   inflating: Univariate_arff/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TEST.arff
#   inflating: Univariate_arff/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TEST.txt
#   inflating: Univariate_arff/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TRAIN.arff
#   inflating: Univariate_arff/UWaveGestureLibraryAll/UWaveGestureLibraryAll_TRAIN.txt
#    creating: Univariate_arff/UWaveGestureLibraryX/
#   inflating: Univariate_arff/UWaveGestureLibraryX/UWaveGestureLibraryX.txt
#   inflating: Univariate_arff/UWaveGestureLibraryX/UWaveGestureLibraryX_TEST.arff
#   inflating: Univariate_arff/UWaveGestureLibraryX/UWaveGestureLibraryX_TEST.txt
#   inflating: Univariate_arff/UWaveGestureLibraryX/UWaveGestureLibraryX_TRAIN.arff
#   inflating: Univariate_arff/UWaveGestureLibraryX/UWaveGestureLibraryX_TRAIN.txt
#    creating: Univariate_arff/UWaveGestureLibraryY/
#   inflating: Univariate_arff/UWaveGestureLibraryY/UWaveGestureLibraryY.txt
#   inflating: Univariate_arff/UWaveGestureLibraryY/UWaveGestureLibraryY_TEST.arff
#   inflating: Univariate_arff/UWaveGestureLibraryY/UWaveGestureLibraryY_TEST.txt
#   inflating: Univariate_arff/UWaveGestureLibraryY/UWaveGestureLibraryY_TRAIN.arff
#   inflating: Univariate_arff/UWaveGestureLibraryY/UWaveGestureLibraryY_TRAIN.txt
#    creating: Univariate_arff/UWaveGestureLibraryZ/
#   inflating: Univariate_arff/UWaveGestureLibraryZ/UWaveGestureLibraryZ.txt
#   inflating: Univariate_arff/UWaveGestureLibraryZ/UWaveGestureLibraryZ_TEST.arff
#   inflating: Univariate_arff/UWaveGestureLibraryZ/UWaveGestureLibraryZ_TEST.txt
#   inflating: Univariate_arff/UWaveGestureLibraryZ/UWaveGestureLibraryZ_TRAIN.arff
#   inflating: Univariate_arff/UWaveGestureLibraryZ/UWaveGestureLibraryZ_TRAIN.txt
#    creating: Univariate_arff/Wafer/
#   inflating: Univariate_arff/Wafer/Wafer.txt
#   inflating: Univariate_arff/Wafer/Wafer_TEST.arff
#   inflating: Univariate_arff/Wafer/Wafer_TEST.txt
#   inflating: Univariate_arff/Wafer/Wafer_TRAIN.arff
#   inflating: Univariate_arff/Wafer/Wafer_TRAIN.txt
#    creating: Univariate_arff/Wine/
#   inflating: Univariate_arff/Wine/Wine.txt
#   inflating: Univariate_arff/Wine/Wine_TEST.arff
#   inflating: Univariate_arff/Wine/Wine_TEST.txt
#   inflating: Univariate_arff/Wine/Wine_TRAIN.arff
#   inflating: Univariate_arff/Wine/Wine_TRAIN.txt
#    creating: Univariate_arff/WordSynonyms/
#   inflating: Univariate_arff/WordSynonyms/WordSynonyms.txt
#   inflating: Univariate_arff/WordSynonyms/WordSynonyms_TEST.arff
#   inflating: Univariate_arff/WordSynonyms/WordSynonyms_TEST.txt
#   inflating: Univariate_arff/WordSynonyms/WordSynonyms_TRAIN.arff
#   inflating: Univariate_arff/WordSynonyms/WordSynonyms_TRAIN.txt
#    creating: Univariate_arff/Worms/
#    creating: Univariate_arff/WormsTwoClass/
#   inflating: Univariate_arff/WormsTwoClass/WormsTwoClass.txt
#   inflating: Univariate_arff/WormsTwoClass/WormsTwoClass_TEST.arff
#   inflating: Univariate_arff/WormsTwoClass/WormsTwoClass_TEST.txt
#   inflating: Univariate_arff/WormsTwoClass/WormsTwoClass_TRAIN.arff
#   inflating: Univariate_arff/WormsTwoClass/WormsTwoClass_TRAIN.txt
#   inflating: Univariate_arff/Worms/Worms.txt
#   inflating: Univariate_arff/Worms/Worms_TEST.arff
#   inflating: Univariate_arff/Worms/Worms_TEST.txt
#   inflating: Univariate_arff/Worms/Worms_TRAIN.arff
#   inflating: Univariate_arff/Worms/Worms_TRAIN.txt
#    creating: Univariate_arff/Yoga/
#   inflating: Univariate_arff/Yoga/Yoga.txt
#   inflating: Univariate_arff/Yoga/Yoga_TEST.arff
#   inflating: Univariate_arff/Yoga/Yoga_TEST.txt
#   inflating: Univariate_arff/Yoga/Yoga_TRAIN.arff
#   inflating: Univariate_arff/Yoga/Yoga_TRAIN.txt

# %%
# In order to perform 10-fold cross-validation, we
# will merge the provided train and test splits and
# we will split the data during the cross-validation

def load_data(file_name_prefix):
  train_data_with_class_labels = np.genfromtxt(file_name_prefix+'_TRAIN.txt')
  test_data_with_class_labels = np.genfromtxt(file_name_prefix+'_TEST.txt')

  data_with_class_labels = np.vstack( (train_data_with_class_labels,
                                      test_data_with_class_labels))
  data_without_class_labels = data_with_class_labels[:,1:]

  return data_without_class_labels, data_with_class_labels[:,0]

# %%
# %load_ext cython

# %%
# %%cython
#
# cimport cython
# from libc.stdlib cimport malloc, free
#
#
# def dtw(ts1p, ts2p):
#     cdef int LEN_TS1
#     cdef int LEN_TS2
#     cdef int i
#     cdef int j
#     cdef float * ts1
#     cdef float * ts2
#     cdef float * dtw_matrix
#     cdef float d
#
#     LEN_TS1 = len(ts1p)
#     LEN_TS2 = len(ts2p)
#
#     ts1 = <float *> malloc(LEN_TS1*cython.sizeof(float))
#     ts2 = <float *> malloc(LEN_TS2*cython.sizeof(float))
#     dtw_matrix = <float *> malloc(LEN_TS1*LEN_TS2*cython.sizeof(float))
#       # this is a flattened DTW matrix dtw_matrix[i,j] -> dtw_matrix[i*LEN_TS2 + j]
#     if ts1 is NULL or ts2 is NULL:
#       raise MemoryError()
#     for i in xrange(LEN_TS1):
#       ts1[i] = ts1p[i]
#     for i in xrange(LEN_TS2):
#       ts2[i] = ts2p[i]
#
#     dtw_matrix[0] = abs(ts1[0]-ts2[0])
#
#     for i in range(1, LEN_TS1):
#       dtw_matrix[i*LEN_TS2] = dtw_matrix[(i-1)*LEN_TS2]+abs(ts1[i]-ts2[0])
#
#     for j in range(1, LEN_TS2):
#       dtw_matrix[j] = dtw_matrix[j-1]+abs(ts1[0]-ts2[j])
#
#     for i in range(1, LEN_TS1):
#       for j in range(1, LEN_TS2):
#         dtw_matrix[i*LEN_TS2+j] = min(dtw_matrix[(i-1)*LEN_TS2+j-1],
#                                       dtw_matrix[(i-1)*LEN_TS2+j],
#                                       dtw_matrix[i*LEN_TS2+j-1]) + abs(ts1[i]-ts2[j])
#
#     d=dtw_matrix[ LEN_TS1*LEN_TS2-1 ]
#
#     free(ts1)
#     free(ts2)
#     free(dtw_matrix)
#
#     return d

# %%
def log2(x):
  return np.log(x)/np.log(2)


def get_random_convolution_params(seed, l_input):
  rnd.seed(seed)
  length = rnd.randint(0,2)*2+7
  weights = rnd.normal(0,1,length)
  bias = float(rnd.uniform(-1, 1))
  max_exp = np.floor(log2((l_input-1)/(length-1)))-1
  dilation = int( 2**(rnd.uniform(0,max_exp)) )
  padding = rnd.randint(0,1)
  return (length, weights, bias, dilation, padding)


def apply_convolution( time_series, convolution ):
  length, weights, bias, dilation, padding = convolution
  window_size = length*dilation
  time_series = list(time_series)

  if padding == 1:
    zeros = [0]*(dilation*(length-1)/2)
    time_series = zeros + time_series + zeros

  segments = np.array(
      [ time_series[i:i+window_size:dilation]
        for i in range(0, int(len(time_series)-window_size)) ] )

  weights_mat = weights.reshape(length,1)

  conv = ((segments@weights_mat) + bias)
  conv = conv.reshape(len(segments))

  dtw_conv = np.array( [dtw(s, weights) for s in segments] )

  return conv, dtw_conv


def ppv(series):
  return float(np.sum(series > 0) / np.size(series))


def get_rocket_features(time_series_dataset, convolutional_filters):
  dataset_features_max = [] # features with conventional convolution and max pooling
  dataset_features_ppv = [] # features with conventional convolution and PPV pooling
  dataset_features_dtw = [] # features with dynamic convolution and max pooling
  for ts in time_series_dataset:
    ts_features_max = []
    ts_features_ppv = []
    ts_features_dtw = []
    for c in convolutional_filters:
      convolved_ts, dtw_convolved_ts = apply_convolution(ts, c)
      ts_features_max.append( float(max(convolved_ts)) )
      ts_features_ppv.append( ppv(convolved_ts) )
      ts_features_dtw.append( float(max(dtw_convolved_ts)) )
    dataset_features_max.append( ts_features_max )
    dataset_features_ppv.append( ts_features_ppv )
    dataset_features_dtw.append( ts_features_dtw )
  return np.array(dataset_features_max), np.array(dataset_features_ppv), np.array(dataset_features_dtw)

# %%
def experiment(dataset):
  X,y = load_data( f"Univariate_arff/{dataset}/{dataset}")
  kf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

  all_acc_rocket = []
  all_acc_dynamicRocket = []

  fold = 0
  print(f"FOLD  ROCKET  DynamicROCKET")
  for train_index, test_index in kf.split(X, y):
    fold = fold + 1

    # Convolutional filters are the same for ROCKET and DynamicROCKET
    convolutional_filters = []
    for i in range(10000):
      convolutional_filters.append(get_random_convolution_params(i, len(X[0])))

    # training data features
    features_train_max, features_train_ppv, features_train_dtw = get_rocket_features(X[train_index], convolutional_filters)

    # training labels
    y_train = y[train_index]

    # train ROCKET
    rocket = RidgeClassifier()
    rocket.fit( np.hstack((features_train_max, features_train_ppv)), y_train)

    # train DynamicROCKET
    dynamic_rocket = RidgeClassifier()
    dynamic_rocket.fit( np.hstack((features_train_dtw, features_train_max, features_train_ppv)), y_train)


    # test data features
    features_test_max, features_test_ppv, features_test_dtw = get_rocket_features(X[test_index], convolutional_filters)

    # test labels
    y_test  = y[test_index]

    # test ROCKET
    pred = rocket.predict( np.hstack((features_test_max, features_test_ppv)) )
    acc = np.mean(pred == y_test)
    all_acc_rocket.append(acc)

    # test DynamicROCKET
    pred = dynamic_rocket.predict( np.hstack((features_test_dtw, features_test_max, features_test_ppv)) )
    acc_d = np.mean(pred == y_test)
    all_acc_dynamicRocket.append(acc_d)

    print(f"{fold:4}  {acc:6.4f}  {acc_d:6.4f} ")

  significant = "No"
  if ttest_rel(all_acc_rocket, all_acc_dynamicRocket)[1] < 0.05:
    significant = "Yes"
  print(f"ROCKET mean accuracy:         {np.mean(all_acc_rocket):6.4f} ")
  print(f"       standard deviation:    {np.std(all_acc_rocket):6.4f}")
  print(f"DynamicROCKET mean accuracy:  {np.mean(all_acc_dynamicRocket):6.4f}")
  print(f"       standard deviation:    {np.std(all_acc_dynamicRocket):6.4f}")
  print(f"Significant:                  {significant}")

# %%
experiment("ECG200") # Change the name of the dataset here for experiments on other datasets
# Out:
# FOLD  ROCKET  DynamicROCKET
#    1  0.8500  0.8500
#    2  0.9000  0.8500
#    3  0.8500  0.8000
#    4  0.9500  0.9000
#    5  0.7000  0.8000
#    6  0.9500  0.9000
#    7  1.0000  0.9500
#    8  0.8500  0.9000
#    9  0.9500  0.9500
#   10  0.8000  0.9000
# ROCKET mean accuracy:         0.8800
#        standard deviation:    0.0843
# DynamicROCKET mean accuracy:  0.8800
#        standard deviation:    0.0510
# Significant:                  No
